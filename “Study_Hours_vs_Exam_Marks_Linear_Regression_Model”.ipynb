# %% [markdown]
# # **“Study Hours vs Exam Marks Linear Regression Model”**

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Data: Hours studied (X) and Marks (y)
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([35, 40, 50, 60, 70])

# Create and train model
model = LinearRegression()
model.fit(X, y)

# Prediction
hours = np.array([[6]])
predicted_marks = model.predict(hours)

print("Predicted marks for 6 hours study:", predicted_marks[0])

# Visualization
plt.scatter(X, y)
plt.plot(X, model.predict(X))
plt.xlabel("Hours Studied")
plt.ylabel("Marks")
plt.show()
# Out:
# Predicted marks for 6 hours study: 78.0
